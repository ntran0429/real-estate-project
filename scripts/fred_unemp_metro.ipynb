# %%
import os
from dotenv import load_dotenv
import requests
import pandas as pd
import matplotlib as plt
import json
from fredapi import Fred

# %%
load_dotenv()
fred_api_key = os.getenv("FRED_API_KEY")
fred = Fred(api_key=fred_api_key)

# %% [markdown]
# Moving average:
#
#     A calculation that smoothes a volatile data series by averaging neighboring data points.
#
# Seasonal adjustment:
#
#     The type of smoothing technique in which seasonal fluctuations in the data are estimated and removed.
#
# Smoothing technique:
#
#     A statistical operation performed on economic data series to reduce or eliminate short-term volatility.

# %%
df_unemp = fred.search('unemployment rate metropolitan', filter=('frequency','Monthly'))
df_unemp = df_unemp.query('seasonal_adjustment == "Smoothed Seasonally Adjusted" and units == "Percent"')
# filter for only unemployment rate in title
df_unemp = df_unemp.loc[df_unemp['title'].str.contains('Unemployment Rate')]

# %%
df_unemp.shape
# Out:
# (348, 15)

# %%
df_unemp
# Out:
#                   id realtime_start realtime_end  \
# series id
# AUST448UR  AUST448UR     2024-01-30   2024-01-30
# DETR826UR  DETR826UR     2024-01-30   2024-01-30
# CHIC917UR  CHIC917UR     2024-01-30   2024-01-30
# SEAT653UR  SEAT653UR     2024-01-30   2024-01-30
# DALL148UR  DALL148UR     2024-01-30   2024-01-30
# ...              ...            ...          ...
# HINE913UR  HINE913UR     2024-01-30   2024-01-30
# OCEA134UR  OCEA134UR     2024-01-30   2024-01-30
# NAPA906UR  NAPA906UR     2024-01-30   2024-01-30
# MORR147UR  MORR147UR     2024-01-30   2024-01-30
# MADE406UR  MADE406UR     2024-01-30   2024-01-30
#
#                                                        title  \
# series id
# AUST448UR   Unemployment Rate in Austin-Round Rock, TX (MSA)
# DETR826UR  Unemployment Rate in Detroit-Warren-Dearborn, ...
# CHIC917UR  Unemployment Rate in Chicago-Naperville-Elgin,...
# SEAT653UR  Unemployment Rate in Seattle-Tacoma-Bellevue, ...
# DALL148UR  Unemployment Rate in Dallas-Fort Worth-Arlingt...
# ...                                                      ...
# HINE913UR          Unemployment Rate in Hinesville, GA (MSA)
# OCEA134UR          Unemployment Rate in Ocean City, NJ (MSA)
# NAPA906UR                Unemployment Rate in Napa, CA (MSA)
# MORR147UR          Unemployment Rate in Morristown, TN (MSA)
# MADE406UR              Unemployment Rate in Madera, CA (MSA)
#
#           observation_start observation_end frequency frequency_short  \
# series id
# AUST448UR        1990-01-01      2023-11-01   Monthly               M
# DETR826UR        1990-01-01      2023-11-01   Monthly               M
# CHIC917UR        1990-01-01      2023-11-01   Monthly               M
# SEAT653UR        1990-01-01      2023-11-01   Monthly               M
# DALL148UR        1990-01-01      2023-11-01   Monthly               M
# ...                     ...             ...       ...             ...
# HINE913UR        1990-01-01      2023-11-01   Monthly               M
# OCEA134UR        1990-01-01      2023-11-01   Monthly               M
# NAPA906UR        1990-01-01      2023-11-01   Monthly               M
# MORR147UR        1990-01-01      2023-11-01   Monthly               M
# MADE406UR        1990-01-01      2023-11-01   Monthly               M
#
#              units units_short           seasonal_adjustment  \
# series id
# AUST448UR  Percent           %  Smoothed Seasonally Adjusted
# DETR826UR  Percent           %  Smoothed Seasonally Adjusted
# CHIC917UR  Percent           %  Smoothed Seasonally Adjusted
# SEAT653UR  Percent           %  Smoothed Seasonally Adjusted
# DALL148UR  Percent           %  Smoothed Seasonally Adjusted
# ...            ...         ...                           ...
# HINE913UR  Percent           %  Smoothed Seasonally Adjusted
# OCEA134UR  Percent           %  Smoothed Seasonally Adjusted
# NAPA906UR  Percent           %  Smoothed Seasonally Adjusted
# MORR147UR  Percent           %  Smoothed Seasonally Adjusted
# MADE406UR  Percent           %  Smoothed Seasonally Adjusted
#
#           seasonal_adjustment_short               last_updated popularity  \
# series id
# AUST448UR                       SSA  2024-01-05 14:54:09-06:00          6
# DETR826UR                       SSA  2024-01-05 14:54:14-06:00          3
# CHIC917UR                       SSA  2024-01-05 14:54:25-06:00          3
# SEAT653UR                       SSA  2024-01-05 14:54:05-06:00          4
# DALL148UR                       SSA  2024-01-05 14:54:27-06:00          3
# ...                             ...                        ...        ...
# HINE913UR                       SSA  2024-01-05 14:54:33-06:00          1
# OCEA134UR                       SSA  2024-01-05 14:54:44-06:00          1
# NAPA906UR                       SSA  2024-01-05 14:55:20-06:00          1
# MORR147UR                       SSA  2024-01-05 14:54:42-06:00          1
# MADE406UR                       SSA  2024-01-05 14:55:22-06:00          1
#
#           notes
# series id
# AUST448UR  None
# DETR826UR  None
# CHIC917UR  None
# SEAT653UR  None
# DALL148UR  None
# ...         ...
# HINE913UR  None
# OCEA134UR  None
# NAPA906UR  None
# MORR147UR  None
# MADE406UR  None
#
# [348 rows x 15 columns]

# %%
unemp_result = df_unemp[df_unemp['title'].str.endswith('(MSA)')]

# %%
unemp_result.shape
# Out:
# (347, 15)

# %%
unemp_result.id.unique()
# Out:
# array(['AUST448UR', 'DETR826UR', 'CHIC917UR', 'SEAT653UR', 'DALL148UR',
#        'ATLA013UR', 'HOUS448UR', 'PHOE004UR', 'JACK212UR', 'TAMP312UR',
#        'CHAR737UR', 'STLUR', 'DENV708UR', 'PITT342UR', 'MPHUR',
#        'MINN427UR', 'LASV832UR', 'CINC139UR', 'SANF806UR', 'LOSA106UR',
#        'NEWY636UR', 'ORLA712UR', 'CLEV439UR', 'INDI918UR', 'KANS129UR',
#        'COLU139UR', 'PORT941UR', 'MIAM112UR', 'CHAT847UR', 'WASH911UR',
#        'ROCH336UR', 'SANA748UR', 'RICH051UR', 'HUNT601UR', 'SANJ906UR',
#        'LOIUR', 'MADI555UR', 'BOIS216UR', 'TUCS004UR', 'FASUR',
#        'MYRT845UR', 'RALE537UR', 'TULS140UR', 'BUFF336UR', 'TOLE739UR',
#        'ALBU735UR', 'SHRE322UR', 'OMAH531UR', 'OKLA440UR', 'WICH620UR',
#        'GRAN326UR', 'RENO932UR', 'SAVA313UR', 'SYRA036UR', 'COLU945UR',
#        'COLO808UR', 'NEWO322UR', 'ASHE737UR', 'NASH947UR', 'BALT524UR',
#        'PHIL942UR', 'SAND706UR', 'SALT649UR', 'BIRM801UR', 'GREE637UR',
#        'MILW355UR', 'DAYT339UR', 'CHAR745UR', 'DESM719UR', 'FARG038UR',
#        'LINC731UR', 'LEWI316UR', 'FLIN426UR', 'CAPE912UR', 'ELCE906UR',
#        'EUGE641UR', 'DURH537UR', 'OCAL112UR', 'BAKE506UR', 'VISA306UR',
#        'OLYM553UR', 'ALLE942UR', 'DELT612UR', 'STOC706UR', 'KNOX947UR',
#        'ROME613UR', 'LRSUR', 'SCRA542UR', 'READ742UR', 'SPIUR', 'ELZUR',
#        'ELPA348UR', 'FAYE137UR', 'SIOU646UR', 'LAKE322UR', 'JACK128UR',
#        'TREN934UR', 'ANDE318UR', 'COLL748UR', 'PBFUR', 'SPRI117UR',
#        'LUBB148UR', 'DAVE317UR', 'ELKH118UR', 'AUGU213UR', 'SANT206UR',
#        'DOTH001UR', 'BILL730UR', 'RIVE106UR', 'MOBI601UR', 'MONT801UR',
#        'FORT018UR', 'CORP548UR', 'BELL353UR', 'AKRO439UR', 'LANC542UR',
#        'BURL537UR', 'CHEY956UR', 'YUMA704UR', 'WATE919UR', 'GAIN512UR',
#        'PORT912UR', 'WACO348UR', 'VIRG251UR', 'JANE555UR', 'LAKE412UR',
#        'DOVE110UR', 'MACO413UR', 'GREE845UR', 'COEU616UR', 'TALL212UR',
#        'GREE555UR', 'COLU913UR', 'MCAL548UR', 'BOUL508UR', 'HARR551UR',
#        'ITHA036UR', 'MEDF741UR', 'JOHN747UR', 'YOUN639UR', 'ROCK417UR',
#        'VICT048UR', 'DULU227UR', 'WILM937UR', 'VINE234UR', 'ATHE013UR',
#        'SACR906UR', 'FORT608UR', 'LAFA118UR', 'LEXI421UR', 'MIDL248UR',
#        'SOUT718UR', 'KILL648UR', 'BATO922UR', 'PENS812UR', 'ROAN251UR',
#        'JACK337UR', 'HUNT554UR', 'LANS626UR', 'ERIE542UR', 'FTSUR',
#        'MORG054UR', 'ROCH327UR', 'FORT012UR', 'DANV117UR', 'FRES406UR',
#        'CLHUR', 'OXNA106UR', 'GREE737UR', 'JEFUR', 'SALE441UR',
#        'ANCH202UR', 'RAPI646UR', 'BREM753UR', 'DECA517UR', 'APPL555UR',
#        'GRAN308UR', 'GREE508UR', 'SANT106UR', 'BING736UR', 'CEDA319UR',
#        'KENN453UR', 'HARR442UR', 'BOWUR', 'WINS137UR', 'CASP256UR',
#        'ANNA426UR', 'CHAR654UR', 'SPAR945UR', 'SPOK053UR', 'FLAG304UR',
#        'EVNUR', 'KOKO018UR', 'HATT628UR', 'BATT926UR', 'UTIC536UR',
#        'AMAR148UR', 'KALA026UR', 'GULF028UR', 'SALI524UR', 'SANT006UR',
#        'MERC906UR', 'KANK117UR', 'TEXUR', 'PARK654UR', 'TYLE348UR',
#        'BLOO017UR', 'PROV349UR', 'BEND441UR', 'ABIL148UR', 'BEAU148UR',
#        'LARE748UR', 'HOLL126UR', 'TUSC201UR', 'VALL706UR', 'ANNI501UR',
#        'GRAN238UR', 'NAPL912UR', 'AUBU201UR', 'STCL027UR', 'ATLA134UR',
#        'MUSK726UR', 'ODES248UR', 'CLMUR', 'IDAH816UR', 'SALI506UR',
#        'CARS132UR', 'CHIC006UR', 'LAWT040UR', 'HSPUR', 'OGDE249UR',
#        'SPRI239UR', 'AMES119UR', 'BROW148UR', 'GADS401UR', 'TOPE820UR',
#        'YORK642UR', 'PALM312UR', 'LAFA122UR', 'BAYC026UR', 'WICH648UR',
#        'ALBA513UR', 'HONO115UR', 'SEBA612UR', 'LEBA142UR', 'CANT939UR',
#        'COLU018UR', 'OWNUR', 'YAKI453UR', 'STGE149UR', 'JORUR',
#        'STJO129UR', 'PANA412UR', 'MONR722UR', 'LONG948UR', 'FAIR802UR',
#        'SAGI926UR', 'ALBA536UR', 'HICK837UR', 'JACUR', 'VALD613UR',
#        'REDD806UR', 'DALT113UR', 'HAGE124UR', 'GOLD137UR', 'CHAR851UR',
#        'IOWA919UR', 'SUMT945UR', 'MUNC618UR', 'GREA530UR', 'LIMA639UR',
#        'DECA401UR', 'SIOU519UR', 'PEOR917UR', 'RACI555UR', 'FLOR501UR',
#        'JOPL929UR', 'LAWR920UR', 'BLOO018UR', 'PRES104UR', 'CLEV447UR',
#        'ELMI336UR', 'GAIN513UR', 'MODE706UR', 'FARM135UR', 'TERR418UR',
#        'CHAM517UR', 'YUBA706UR', 'PUNT412UR', 'SHEB155UR', 'MONR726UR',
#        'PUEB308UR', 'KING747UR', 'CUMB024UR', 'SANL006UR', 'JOHN742UR',
#        'WHEE554UR', 'SANT135UR', 'WARN513UR', 'SHER348UR', 'DUBU219UR',
#        'SANA648UR', 'STAT342UR', 'LACR155UR', 'BISM938UR', 'EAUC755UR',
#        'BRUN213UR', 'ROCK537UR', 'FLOR545UR', 'SARA212UR', 'WILL742UR',
#        'LONG053UR', 'WEIR239UR', 'HANF206UR', 'PALM412UR', 'LOGA849UR',
#        'LASC735UR', 'LYNC351UR', 'MISS530UR', 'WENA353UR', 'BLAC951UR',
#        'KING736UR', 'MICH118UR', 'PASC728UR', 'WINC051UR', 'DANV251UR',
#        'POUG136UR', 'MANS939UR', 'WAUS155UR', 'JACK126UR', 'NILE626UR',
#        'GLEN036UR', 'ALTO042UR', 'CORV741UR', 'ANDE345UR', 'SAND739UR',
#        'FOND555UR', 'POCA516UR', 'ALEX722UR', 'HOUM322UR', 'OSHK755UR',
#        'MOUN553UR', 'HINE913UR', 'OCEA134UR', 'NAPA906UR', 'MORR147UR',
#        'MADE406UR'], dtype=object)

# %%
all_result =[]

for id in unemp_result.index:
    result = fred.get_series(id)
    result = result.to_frame(name = id)
    all_result.append(result)

# %%
all_result[1]
# Out:
#             DETR826UR
# 1990-01-01        7.6
# 1990-02-01        7.6
# 1990-03-01        7.5
# 1990-04-01        7.6
# 1990-05-01        7.6
# ...               ...
# 2023-07-01        3.0
# 2023-08-01        3.2
# 2023-09-01        3.4
# 2023-10-01        3.8
# 2023-11-01        4.1
#
# [407 rows x 1 columns]

# %%
unemp_state = pd.concat(all_result, axis=1)

# %%
unemp_state.tail()
# Out:
#             AUST448UR  DETR826UR  CHIC917UR  SEAT653UR  DALL148UR  ATLA013UR  \
# 2023-07-01        3.5        3.0        3.9        3.3        3.8        3.1
# 2023-08-01        3.6        3.2        4.1        3.4        3.9        3.2
# 2023-09-01        3.6        3.4        4.4        3.5        3.9        3.3
# 2023-10-01        3.6        3.8        4.6        3.6        3.9        3.3
# 2023-11-01        3.5        4.1        4.7        3.8        3.8        3.4
#
#             HOUS448UR  PHOE004UR  JACK212UR  TAMP312UR  ...  POCA516UR  \
# 2023-07-01        4.4        3.4        2.7        2.7  ...        2.9
# 2023-08-01        4.5        3.5        2.8        2.8  ...        3.0
# 2023-09-01        4.5        3.6        2.9        2.9  ...        3.1
# 2023-10-01        4.4        3.7        2.9        3.0  ...        3.2
# 2023-11-01        4.4        3.8        3.0        3.0  ...        3.3
#
#             ALEX722UR  HOUM322UR  OSHK755UR  MOUN553UR  HINE913UR  OCEA134UR  \
# 2023-07-01        3.1        3.2        2.3        4.1        3.3        6.7
# 2023-08-01        3.0        3.0        2.5        4.0        3.4        7.0
# 2023-09-01        3.0        3.1        2.7        4.0        3.4        7.2
# 2023-10-01        3.1        3.1        2.8        4.2        3.4        7.4
# 2023-11-01        3.3        3.2        2.9        4.4        3.4        7.4
#
#             NAPA906UR  MORR147UR  MADE406UR
# 2023-07-01        3.5        3.5        7.4
# 2023-08-01        3.5        3.5        7.5
# 2023-09-01        3.6        3.6        7.5
# 2023-10-01        3.7        3.7        7.6
# 2023-11-01        3.7        3.7        7.6
#
# [5 rows x 347 columns]

# %%
id_to_state = df_unemp['title'].str.replace('Unemployment Rate in ','').to_dict()

# %%
unemp_state.columns = [id_to_state[d] for d in unemp_state.columns]

# %%
unemp_state.columns
# Out:
# Index(['Austin-Round Rock, TX (MSA)', 'Detroit-Warren-Dearborn, MI (MSA)',
#        'Chicago-Naperville-Elgin, IL-IN-WI (MSA)',
#        'Seattle-Tacoma-Bellevue, WA (MSA)',
#        'Dallas-Fort Worth-Arlington, TX (MSA)',
#        'Atlanta-Sandy Springs-Roswell, GA (MSA)',
#        'Houston-The Woodlands-Sugar Land, TX (MSA)',
#        'Phoenix-Mesa-Scottsdale, AZ (MSA)', 'Jacksonville, FL (MSA)',
#        'Tampa-St. Petersburg-Clearwater, FL (MSA)',
#        ...
#        'Pocatello, ID (MSA)', 'Alexandria, LA (MSA)',
#        'Houma-Thibodaux, LA (MSA)', 'Oshkosh-Neenah, WI (MSA)',
#        'Mount Vernon-Anacortes, WA (MSA)', 'Hinesville, GA (MSA)',
#        'Ocean City, NJ (MSA)', 'Napa, CA (MSA)', 'Morristown, TN (MSA)',
#        'Madera, CA (MSA)'],
#       dtype='object', length=347)

# %%
unemp_state.tail()
# Out:
#             Austin-Round Rock, TX (MSA)  Detroit-Warren-Dearborn, MI (MSA)  \
# 2023-07-01                          3.5                                3.0
# 2023-08-01                          3.6                                3.2
# 2023-09-01                          3.6                                3.4
# 2023-10-01                          3.6                                3.8
# 2023-11-01                          3.5                                4.1
#
#             Chicago-Naperville-Elgin, IL-IN-WI (MSA)  \
# 2023-07-01                                       3.9
# 2023-08-01                                       4.1
# 2023-09-01                                       4.4
# 2023-10-01                                       4.6
# 2023-11-01                                       4.7
#
#             Seattle-Tacoma-Bellevue, WA (MSA)  \
# 2023-07-01                                3.3
# 2023-08-01                                3.4
# 2023-09-01                                3.5
# 2023-10-01                                3.6
# 2023-11-01                                3.8
#
#             Dallas-Fort Worth-Arlington, TX (MSA)  \
# 2023-07-01                                    3.8
# 2023-08-01                                    3.9
# 2023-09-01                                    3.9
# 2023-10-01                                    3.9
# 2023-11-01                                    3.8
#
#             Atlanta-Sandy Springs-Roswell, GA (MSA)  \
# 2023-07-01                                      3.1
# 2023-08-01                                      3.2
# 2023-09-01                                      3.3
# 2023-10-01                                      3.3
# 2023-11-01                                      3.4
#
#             Houston-The Woodlands-Sugar Land, TX (MSA)  \
# 2023-07-01                                         4.4
# 2023-08-01                                         4.5
# 2023-09-01                                         4.5
# 2023-10-01                                         4.4
# 2023-11-01                                         4.4
#
#             Phoenix-Mesa-Scottsdale, AZ (MSA)  Jacksonville, FL (MSA)  \
# 2023-07-01                                3.4                     2.7
# 2023-08-01                                3.5                     2.8
# 2023-09-01                                3.6                     2.9
# 2023-10-01                                3.7                     2.9
# 2023-11-01                                3.8                     3.0
#
#             Tampa-St. Petersburg-Clearwater, FL (MSA)  ...  \
# 2023-07-01                                        2.7  ...
# 2023-08-01                                        2.8  ...
# 2023-09-01                                        2.9  ...
# 2023-10-01                                        3.0  ...
# 2023-11-01                                        3.0  ...
#
#             Pocatello, ID (MSA)  Alexandria, LA (MSA)  \
# 2023-07-01                  2.9                   3.1
# 2023-08-01                  3.0                   3.0
# 2023-09-01                  3.1                   3.0
# 2023-10-01                  3.2                   3.1
# 2023-11-01                  3.3                   3.3
#
#             Houma-Thibodaux, LA (MSA)  Oshkosh-Neenah, WI (MSA)  \
# 2023-07-01                        3.2                       2.3
# 2023-08-01                        3.0                       2.5
# 2023-09-01                        3.1                       2.7
# 2023-10-01                        3.1                       2.8
# 2023-11-01                        3.2                       2.9
#
#             Mount Vernon-Anacortes, WA (MSA)  Hinesville, GA (MSA)  \
# 2023-07-01                               4.1                   3.3
# 2023-08-01                               4.0                   3.4
# 2023-09-01                               4.0                   3.4
# 2023-10-01                               4.2                   3.4
# 2023-11-01                               4.4                   3.4
#
#             Ocean City, NJ (MSA)  Napa, CA (MSA)  Morristown, TN (MSA)  \
# 2023-07-01                   6.7             3.5                   3.5
# 2023-08-01                   7.0             3.5                   3.5
# 2023-09-01                   7.2             3.6                   3.6
# 2023-10-01                   7.4             3.7                   3.7
# 2023-11-01                   7.4             3.7                   3.7
#
#             Madera, CA (MSA)
# 2023-07-01               7.4
# 2023-08-01               7.5
# 2023-09-01               7.5
# 2023-10-01               7.6
# 2023-11-01               7.6
#
# [5 rows x 347 columns]

# %%
# export unemp_state to csv
unemp_state.to_csv('../cleansed data/msa_unemp.csv')
