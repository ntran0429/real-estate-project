# %%
# import requests
import pandas as pd
# import os
# from dotenv import load_dotenv

# %% [markdown]
# ## Getting ORI codes

# %%
agencies = pd.read_csv('../cleansed data/via api.data.gov U.S. law enforcement agencies and ORI (Originating Agency Identifier) numbers [collected 2020-06-12] - Sheet1.csv')

# %%
agencies.shape
# Out:
# (18575, 13)

# %%
agencies.head()
# Out:
#          ori                  agency_name  agency_type_name state_name  \
# 0  AK0010100  Anchorage Police Department      Municipality     Alaska
# 1  AK0010200  Fairbanks Police Department           Borough     Alaska
# 2  AK0010300     Juneau Police Department  City and Borough     Alaska
# 3  AK0010400  Ketchikan Police Department           Borough     Alaska
# 4  AK0010500     Kodiak Police Department           Borough     Alaska
#
#   state_abbr division_name region_name region_desc           county_name  \
# 0         AK       Pacific        West   Region IV             ANCHORAGE
# 1         AK       Pacific        West   Region IV  FAIRBANKS NORTH STAR
# 2         AK       Pacific        West   Region IV                JUNEAU
# 3         AK       Pacific        West   Region IV     KETCHIKAN GATEWAY
# 4         AK       Pacific        West   Region IV         KODIAK ISLAND
#
#    nibrs   latitude   longitude nibrs_start_date
# 0  False  61.174250 -149.284329              NaN
# 1  False  64.839450 -147.719420              NaN
# 2  False  58.356556 -134.507310              NaN
# 3  False  55.449938 -131.106685              NaN
# 4  False  57.804900 -152.373320              NaN

# %%
# create a copy of agencies
agencies_copy = agencies.copy()

# %%
agencies_copy['agency_type_name'].unique()
# Out:
# array(['Municipality', 'Borough', 'City and Borough', 'Census Area',
#        'County', 'City', 'University or College', 'Other State Agency',
#        'Other', 'Tribal', 'State Police', 'Parish'], dtype=object)

# %%
# agencies_copy = agencies_copy[agencies_copy['agency_type_name']
#                               .isin(['City', 'Municipality', 'Parish', 'City and Borough'])]

# %%
# remove ' Police Department' in agency_name
agencies_copy['agency_name'] = agencies_copy['agency_name'] \
    .str.replace(' Police Department', '')

# %%
# remove ' Metropolitan' in agency_name
agencies_copy['agency_name'] = agencies_copy['agency_name'] \
    .str.replace(' Metropolitan', '')

# %%
# remove ' Bureau of Police' in agency_name
agencies_copy['agency_name'] = agencies_copy['agency_name'] \
    .str.replace(' Bureau of Police', '')

# %%
# remove ' Metro' in agency_name
agencies_copy['agency_name'] = agencies_copy['agency_name'] \
    .str.replace(' Metro', '')

# %%
cities = pd.read_csv('../raw data/cities.csv')

# %%
cities
# Out:
#               State          City
# 0           Alabama    Huntsville
# 1            Alaska     Anchorage
# 2    American Samoa        Tafuna
# 3           Arizona       Phoenix
# 4          Arkansas   Little Rock
# ..              ...           ...
# 270        Virginia     Arlington
# 271      Washington      Bellevue
# 272   West Virginia      Wheeling
# 273       Wisconsin        Racine
# 274         Wyoming  Rock Springs
#
# [275 rows x 2 columns]

# %%
cities['State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'American Samoa', 'Arizona', 'Arkansas',
#        'California', 'Colorado', 'Connecticut', 'Delaware',
#        'District of Columbia', 'Florida', 'Georgia', 'Guam', 'Hawaii',
#        'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky',
#        'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan',
#        'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska',
#        'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York',
#        'North Carolina', 'North Dakota', 'Northern Mariana Islands',
#        'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Puerto Rico',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virgin Islands (U.S.)', 'Virginia',
#        'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'],
#       dtype=object)

# %%
cities.shape
# Out:
# (275, 2)

# %%
# replace Washington, D.C. in cities with Washington
cities['City'] = cities['City'].replace('Washington, D.C.', 'Washington')

# %%
cities = cities[~cities['State'].isin(['American Samoa', 
                                       'Virgin Islands (U.S.)', 
                                       'Northern Mariana Islands', 
                                       'Guam'])]

# %%
cities.shape
# Out:
# (256, 2)

# %%
def filter_agencies(row):
    '''takes a row from the cities dataframe and 
    filters the agencies_copy dataframe based on the State and City columns.'''
    return agencies_copy[(agencies_copy['agency_name'] == row['City']) 
                         & (agencies_copy['state_name'] == row['State'])]

# Use the apply function on the cities dataframe to apply the function to each row.
filtered_agencies = cities.apply(filter_agencies, axis=1)

# axis: {0 or ‘index’, 1 or ‘columns’}, default 0
# Axis along which the function is applied:
# 0 or ‘index’: apply function to each column.
# 1 or ‘columns’: apply function to each row.

# %%
# return a single dataframe containing only the rows from agencies_copy 
# that match every City and State pair in cities.
filtered_agencies = pd.concat(cities.apply(filter_agencies, axis=1).tolist())

# %%
filtered_agencies
# Out:
#              ori   agency_name agency_type_name     state_name state_abbr  \
# 330    AL0470100    Huntsville             City        Alabama         AL
# 0      AK0010100     Anchorage     Municipality         Alaska         AK
# 817    AZ0072300       Phoenix             City        Arizona         AZ
# 696    AR0600200   Little Rock             City       Arkansas         AR
# 1117   CA0194200   Los Angeles             City     California         CA
# ...          ...           ...              ...            ...        ...
# 17265  VT0020100    Bennington             City        Vermont         VT
# 17416  WA0170200      Bellevue             City     Washington         WA
# 18325  WV0350100      Wheeling             City  West Virginia         WV
# 17918  WI0520200        Racine             City      Wisconsin         WI
# 18563  WY0190200  Rock Springs             City        Wyoming         WY
#
#             division_name region_name region_desc         county_name  nibrs  \
# 330    East South Central       South  Region III  LIMESTONE; MADISON  False
# 0                 Pacific        West   Region IV           ANCHORAGE  False
# 817              Mountain        West   Region IV            MARICOPA  False
# 696    West South Central       South  Region III             PULASKI   True
# 1117              Pacific        West   Region IV         LOS ANGELES  False
# ...                   ...         ...         ...                 ...    ...
# 17265         New England   Northeast    Region I          BENNINGTON   True
# 17416             Pacific        West   Region IV                KING   True
# 18325      South Atlantic       South  Region III      MARSHALL; OHIO   True
# 17918  East North Central     Midwest   Region II              RACINE   True
# 18563            Mountain        West   Region IV          SWEETWATER  False
#
#         latitude   longitude nibrs_start_date
# 330    34.764238  -86.551080              NaN
# 0      61.174250 -149.284329              NaN
# 817    33.448250 -112.081700              NaN
# 696    34.749084  -92.277565       08/01/2002
# 1117   34.196398 -118.261862              NaN
# ...          ...         ...              ...
# 17265  43.035325  -73.111460       01/01/1998
# 17416  47.493554 -121.832375       01/01/2015
# 18325  40.064915  -80.720924       02/01/1999
# 17918  42.725280  -87.789406       01/01/2017
# 18563  41.660339 -108.875676              NaN
#
# [232 rows x 13 columns]

# %%
# select ori, agency_name, state_name, and agency_type_name columns
filtered_agencies = filtered_agencies[['ori', 'agency_name', 'state_name', 'agency_type_name']]

# %%
# output filtered_agencies to a csv file
filtered_agencies.to_csv('../cleansed data/agencies.csv', index=False)

# %%
# find out which City in cities are not in agencies_copy
missing_cities = cities[~cities['City'].isin(filtered_agencies['agency_name'])]

# %%
# order missing_cities by State
missing_cities.sort_values(by='State')
# Out:
#               State              City
# 176         Georgia             Macon
# 121         Georgia           Augusta
# 231         Georgia          Savannah
# 68           Hawaii    East Honolulu
# 123          Hawaii        Pearl City
# 233          Hawaii            Kailua
# 178          Hawaii              Hilo
# 132        Maryland        Germantown
# 242        Maryland           Waldorf
# 187        Maryland     Silver Spring
# 80        Minnesota        Saint Paul
# 82         Missouri       Saint Louis
# 248         Montana             Butte
# 250          Nevada          Paradise
# 252      New Jersey            Edison
# 35   North Carolina         Charlotte
# 261     Puerto Rico            Caguas
# 152     Puerto Rico          Carolina
# 97      Puerto Rico           Bayamón
# 42      Puerto Rico          San Juan
# 207     Puerto Rico             Ponce
# 103            Utah  West Valley City
# 270        Virginia         Arlington

# %%
missing_cities.shape
# Out:
# (23, 2)
