# %%
import googleapiclient.discovery
import pandas as pd

# %%
api_service_name = "youtube"
api_version = "v3"
DEVELOPER_KEY = "AIzaSyC1fvCbxCdGlrjgpwA4c0jfMIwaPOdRW-I"

# %%
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey=DEVELOPER_KEY)

# %%
def getcomments(video):
  request = youtube.commentThreads().list(
      part="snippet",
      videoId=video,
      maxResults=100
  )

  comments = []

  # Execute the request.
  response = request.execute()

  # Get the comments from the response.
  for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  while (1 == 1):
    try:
     nextPageToken = response['nextPageToken']
    except KeyError:
     break
    nextPageToken = response['nextPageToken']
    # Create a new request object with the next page token.
    nextRequest = youtube.commentThreads().list(part="snippet", videoId=video, maxResults=100, pageToken=nextPageToken)
    # Execute the next request.
    response = nextRequest.execute()
    # Get the comments from the next response.
    for item in response['items']:
      comment = item['snippet']['topLevelComment']['snippet']
      public = item['snippet']['isPublic']
      comments.append([
          comment['authorDisplayName'],
          comment['publishedAt'],
          comment['likeCount'],
          comment['textOriginal'],
          comment['videoId'],
          public
      ])

  df2 = pd.DataFrame(comments, columns=['author', 'published_at', 'like_count', 'text','video_id','public'])
  return df2

# %% [markdown]
# g1bOstgCQsM - [Buying vs Renting a Home: Which is BETTER in 2023?](https://www.youtube.com/watch?v=g1bOstgCQsM)
#
# b1FEzd9TUDE - [Buy A Home or Keep Renting?](https://www.youtube.com/watch?v=b1FEzd9TUDE)
#
# LzK2rviPo4c - [Rent vs. Buy: Which Makes More Sense In The Current Real Estate Market?](https://www.youtube.com/watch?v=LzK2rviPo4c)
#
# Od40MC_HyNU - [ACCOUNTANT EXPLAINS Should you Rent or Buy Your Home](https://www.youtube.com/watch?v=Od40MC_HyNU)

# %%
df = pd.DataFrame()
for i in ['g1bOstgCQsM','b1FEzd9TUDE','LzK2rviPo4c','Od40MC_HyNU']:
  df2 = getcomments(i)
  df = pd.concat([df, df2])

# %%
df.head(10)
# Out:
#              author          published_at  like_count  \
# 0         @TechLead  2023-11-03T16:40:33Z          17
# 1    @dangunsuh5594  2024-03-04T13:16:37Z           1
# 2  @snake_eater1963  2024-02-14T21:32:20Z           1
# 3      @sewnsew6770  2024-02-11T16:00:57Z           1
# 4         @yoda6051  2024-02-10T03:38:58Z           0
# 5  @slacktronic6587  2024-02-07T15:45:23Z           0
# 6       @Deborah_C1  2024-02-02T03:51:10Z         420
# 7     @melgonz.6962  2024-02-02T00:48:25Z           0
# 8  @user-nl5le9id8v  2024-01-30T23:39:06Z           0
# 9   @jupitereye4322  2024-01-15T20:10:23Z           1
#
#                                                 text     video_id  public
# 0  Right now, the first 500 people to use my link...  g1bOstgCQsM    True
# 1                                            Guru 🎉🎉  g1bOstgCQsM    True
# 2                                      thanks kojima  g1bOstgCQsM    True
# ...

# %%
df.tail(10)
# Out:
#                      author          published_at  like_count  \
# 307               @alleneng  2023-04-17T00:02:45Z           1
# 308       @zukecleaning9838  2023-04-16T20:50:37Z          16
# 309              @larryl164  2023-04-16T19:56:33Z           2
# 310           @fiattenebris  2023-04-16T18:26:54Z          11
# 311                @tomtang  2023-04-16T18:08:15Z           1
# 312                @tcwatt1  2023-04-16T18:00:15Z          22
# 313            @hdmonge2395  2023-04-16T17:23:55Z           4
# 314  @lethukuthulandaba6278  2023-04-16T17:22:55Z           1
# 315  @karamal-hassanieh5477  2023-04-16T17:21:20Z           8
# 316                @1521joe  2023-04-16T16:58:44Z           1
#
#                                                   text     video_id  public
# 307  i would say lease vs financing a car is more o...  Od40MC_HyNU    True
# 308  Great Video Gabrielle.  I am so glad I found y...  Od40MC_HyNU    True
# ...

# %%
df['video_id'].value_counts()
# Out:
# video_id
# LzK2rviPo4c    726
# Od40MC_HyNU    317
# g1bOstgCQsM    206
# b1FEzd9TUDE    148
# Name: count, dtype: int64

# %%
# export to csv file
df.to_csv('../cleansed data/youtube_comments_for_sentiment_analysis.csv', index=False)
