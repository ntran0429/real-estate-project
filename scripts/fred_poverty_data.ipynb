# %%
import os
from dotenv import load_dotenv
import requests
import pandas as pd
import matplotlib as plt
import json
from fredapi import Fred
# Out:
# /var/folders/wr/rqmlsdm96r917lc0k6sr9c640000gn/T/ipykernel_84845/3984096865.py:4: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
load_dotenv()
fred_api_key = os.getenv("FRED_API_KEY")
fred = Fred(api_key=fred_api_key)

# %%
# Percent of People of All Ages in Poverty
df_pov = fred.search('Percent of People of All Ages in Poverty')
# df_inc = df_inc.query('units == "Percent"')

df_pov = df_pov.loc[df_pov['title'].str.contains('Percent of People of All Ages in Poverty')]

# %%
df_pov.shape
# Out:
# (584, 15)

# %%
df_pov
# Out:
#                                               id realtime_start realtime_end  \
# series id
# PPAAUS00000A156NCEN          PPAAUS00000A156NCEN     2024-01-27   2024-01-27
# PPAACA06000A156NCEN          PPAACA06000A156NCEN     2024-01-27   2024-01-27
# PPAACA06037A156NCEN          PPAACA06037A156NCEN     2024-01-27   2024-01-27
# PPAAMS28000A156NCEN          PPAAMS28000A156NCEN     2024-01-27   2024-01-27
# PPAANY36000A156NCEN          PPAANY36000A156NCEN     2024-01-27   2024-01-27
# ...                                          ...            ...          ...
# PPAACA06099A156NCEN          PPAACA06099A156NCEN     2024-01-27   2024-01-27
# PPAAOH39029A156NCEN          PPAAOH39029A156NCEN     2024-01-27   2024-01-27
# PPAAMN27073A156NCEN          PPAAMN27073A156NCEN     2024-01-27   2024-01-27
# PPCILBAANV32000A156NCEN  PPCILBAANV32000A156NCEN     2024-01-27   2024-01-27
# PPCILBAAKY21213A156NCEN  PPCILBAAKY21213A156NCEN     2024-01-27   2024-01-27
#
#                                                                      title  \
# series id
# PPAAUS00000A156NCEN      Estimated Percent of People of All Ages in Pov...
# PPAACA06000A156NCEN      Estimated Percent of People of All Ages in Pov...
# PPAACA06037A156NCEN      Estimated Percent of People of All Ages in Pov...
# PPAAMS28000A156NCEN      Estimated Percent of People of All Ages in Pov...
# PPAANY36000A156NCEN      Estimated Percent of People of All Ages in Pov...
# ...                                                                    ...
# PPAACA06099A156NCEN      Estimated Percent of People of All Ages in Pov...
# PPAAOH39029A156NCEN      Estimated Percent of People of All Ages in Pov...
# PPAAMN27073A156NCEN      Estimated Percent of People of All Ages in Pov...
# PPCILBAANV32000A156NCEN  90% Confidence Interval Lower Bound of Estimat...
# PPCILBAAKY21213A156NCEN  90% Confidence Interval Lower Bound of Estimat...
#
#                         observation_start observation_end frequency  \
# series id
# PPAAUS00000A156NCEN            1989-01-01      2022-01-01    Annual
# PPAACA06000A156NCEN            1989-01-01      2022-01-01    Annual
# PPAACA06037A156NCEN            1989-01-01      2022-01-01    Annual
# PPAAMS28000A156NCEN            1989-01-01      2022-01-01    Annual
# PPAANY36000A156NCEN            1989-01-01      2022-01-01    Annual
# ...                                   ...             ...       ...
# PPAACA06099A156NCEN            1989-01-01      2022-01-01    Annual
# PPAAOH39029A156NCEN            1989-01-01      2022-01-01    Annual
# PPAAMN27073A156NCEN            1989-01-01      2022-01-01    Annual
# PPCILBAANV32000A156NCEN        1989-01-01      2022-01-01    Annual
# PPCILBAAKY21213A156NCEN        1989-01-01      2022-01-01    Annual
#
#                         frequency_short    units units_short  \
# series id
# PPAAUS00000A156NCEN                   A  Percent           %
# PPAACA06000A156NCEN                   A  Percent           %
# PPAACA06037A156NCEN                   A  Percent           %
# PPAAMS28000A156NCEN                   A  Percent           %
# PPAANY36000A156NCEN                   A  Percent           %
# ...                                 ...      ...         ...
# PPAACA06099A156NCEN                   A  Percent           %
# PPAAOH39029A156NCEN                   A  Percent           %
# PPAAMN27073A156NCEN                   A  Percent           %
# PPCILBAANV32000A156NCEN               A  Percent           %
# PPCILBAAKY21213A156NCEN               A  Percent           %
#
#                              seasonal_adjustment seasonal_adjustment_short  \
# series id
# PPAAUS00000A156NCEN      Not Seasonally Adjusted                       NSA
# PPAACA06000A156NCEN      Not Seasonally Adjusted                       NSA
# PPAACA06037A156NCEN      Not Seasonally Adjusted                       NSA
# PPAAMS28000A156NCEN      Not Seasonally Adjusted                       NSA
# PPAANY36000A156NCEN      Not Seasonally Adjusted                       NSA
# ...                                          ...                       ...
# PPAACA06099A156NCEN      Not Seasonally Adjusted                       NSA
# PPAAOH39029A156NCEN      Not Seasonally Adjusted                       NSA
# PPAAMN27073A156NCEN      Not Seasonally Adjusted                       NSA
# PPCILBAANV32000A156NCEN  Not Seasonally Adjusted                       NSA
# PPCILBAAKY21213A156NCEN  Not Seasonally Adjusted                       NSA
#
#                                      last_updated popularity  \
# series id
# PPAAUS00000A156NCEN     2023-12-14 12:51:03-06:00         51
# PPAACA06000A156NCEN     2023-12-14 12:51:04-06:00         11
# PPAACA06037A156NCEN     2023-12-14 12:46:12-06:00          9
# PPAAMS28000A156NCEN     2023-12-14 12:51:17-06:00          7
# PPAANY36000A156NCEN     2023-12-14 12:51:06-06:00          7
# ...                                           ...        ...
# PPAACA06099A156NCEN     2023-12-14 13:34:15-06:00          1
# PPAAOH39029A156NCEN     2023-12-14 12:46:07-06:00          1
# PPAAMN27073A156NCEN     2023-12-14 12:56:52-06:00          1
# PPCILBAANV32000A156NCEN 2023-12-14 13:10:17-06:00          1
# PPCILBAAKY21213A156NCEN 2023-12-14 13:29:49-06:00          1
#
#                                                                      notes
# series id
# PPAAUS00000A156NCEN      The U.S. Census Bureau provides annual estimat...
# PPAACA06000A156NCEN      The U.S. Census Bureau provides annual estimat...
# PPAACA06037A156NCEN      The U.S. Census Bureau provides annual estimat...
# PPAAMS28000A156NCEN      The U.S. Census Bureau provides annual estimat...
# PPAANY36000A156NCEN      The U.S. Census Bureau provides annual estimat...
# ...                                                                    ...
# PPAACA06099A156NCEN      The U.S. Census Bureau provides annual estimat...
# PPAAOH39029A156NCEN      The U.S. Census Bureau provides annual estimat...
# PPAAMN27073A156NCEN      The U.S. Census Bureau provides annual estimat...
# PPCILBAANV32000A156NCEN  The U.S. Census Bureau provides annual estimat...
# PPCILBAAKY21213A156NCEN  The U.S. Census Bureau provides annual estimat...
#
# [584 rows x 15 columns]

# %%
# Percent of People of All Ages in Poverty
