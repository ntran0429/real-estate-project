# %%
import os
from dotenv import load_dotenv
import requests
import pandas as pd
import matplotlib as plt
import json
from fredapi import Fred

# %%
load_dotenv()
fred_api_key = os.getenv("FRED_API_KEY")
fred = Fred(api_key=fred_api_key)

# %%
# Percent of People of All Ages in Poverty
df_pov = fred.search('Percent of People of All Ages in Poverty')
# df_inc = df_inc.query('units == "Percent"')

df_pov = df_pov.loc[df_pov['title'].str.contains('Percent of People of All Ages in Poverty')]

# %%
df_pov.shape
# Out:
# (567, 15)

# %%
df_pov
# Out:
#                                       id realtime_start realtime_end  \
# series id
# PPAAUS00000A156NCEN  PPAAUS00000A156NCEN     2024-01-28   2024-01-28
# PPAACA06037A156NCEN  PPAACA06037A156NCEN     2024-01-28   2024-01-28
# PPAACA06000A156NCEN  PPAACA06000A156NCEN     2024-01-28   2024-01-28
# PPAAPA42000A156NCEN  PPAAPA42000A156NCEN     2024-01-28   2024-01-28
# PPAAIN18000A156NCEN  PPAAIN18000A156NCEN     2024-01-28   2024-01-28
# ...                                  ...            ...          ...
# PPAAWI55000A156NCEN  PPAAWI55000A156NCEN     2024-01-28   2024-01-28
# PPAACA06093A156NCEN  PPAACA06093A156NCEN     2024-01-28   2024-01-28
# PPAAGA13073A156NCEN  PPAAGA13073A156NCEN     2024-01-28   2024-01-28
# PPAAKY21147A156NCEN  PPAAKY21147A156NCEN     2024-01-28   2024-01-28
# PPAACT09009A156NCEN  PPAACT09009A156NCEN     2024-01-28   2024-01-28
#
#                                                                  title  \
# series id
# PPAAUS00000A156NCEN  Estimated Percent of People of All Ages in Pov...
# PPAACA06037A156NCEN  Estimated Percent of People of All Ages in Pov...
# PPAACA06000A156NCEN  Estimated Percent of People of All Ages in Pov...
# PPAAPA42000A156NCEN  Estimated Percent of People of All Ages in Pov...
# PPAAIN18000A156NCEN  Estimated Percent of People of All Ages in Pov...
# ...                                                                ...
# PPAAWI55000A156NCEN  Estimated Percent of People of All Ages in Pov...
# PPAACA06093A156NCEN  Estimated Percent of People of All Ages in Pov...
# PPAAGA13073A156NCEN  Estimated Percent of People of All Ages in Pov...
# PPAAKY21147A156NCEN  Estimated Percent of People of All Ages in Pov...
# PPAACT09009A156NCEN  Estimated Percent of People of All Ages in Pov...
#
#                     observation_start observation_end frequency  \
# series id
# PPAAUS00000A156NCEN        1989-01-01      2022-01-01    Annual
# PPAACA06037A156NCEN        1989-01-01      2022-01-01    Annual
# PPAACA06000A156NCEN        1989-01-01      2022-01-01    Annual
# PPAAPA42000A156NCEN        1989-01-01      2022-01-01    Annual
# PPAAIN18000A156NCEN        1989-01-01      2022-01-01    Annual
# ...                               ...             ...       ...
# PPAAWI55000A156NCEN        1989-01-01      2022-01-01    Annual
# PPAACA06093A156NCEN        1989-01-01      2022-01-01    Annual
# PPAAGA13073A156NCEN        1989-01-01      2022-01-01    Annual
# PPAAKY21147A156NCEN        1989-01-01      2022-01-01    Annual
# PPAACT09009A156NCEN        1989-01-01      2021-01-01    Annual
#
#                     frequency_short    units units_short  \
# series id
# PPAAUS00000A156NCEN               A  Percent           %
# PPAACA06037A156NCEN               A  Percent           %
# PPAACA06000A156NCEN               A  Percent           %
# PPAAPA42000A156NCEN               A  Percent           %
# PPAAIN18000A156NCEN               A  Percent           %
# ...                             ...      ...         ...
# PPAAWI55000A156NCEN               A  Percent           %
# PPAACA06093A156NCEN               A  Percent           %
# PPAAGA13073A156NCEN               A  Percent           %
# PPAAKY21147A156NCEN               A  Percent           %
# PPAACT09009A156NCEN               A  Percent           %
#
#                          seasonal_adjustment seasonal_adjustment_short  \
# series id
# PPAAUS00000A156NCEN  Not Seasonally Adjusted                       NSA
# PPAACA06037A156NCEN  Not Seasonally Adjusted                       NSA
# PPAACA06000A156NCEN  Not Seasonally Adjusted                       NSA
# PPAAPA42000A156NCEN  Not Seasonally Adjusted                       NSA
# PPAAIN18000A156NCEN  Not Seasonally Adjusted                       NSA
# ...                                      ...                       ...
# PPAAWI55000A156NCEN  Not Seasonally Adjusted                       NSA
# PPAACA06093A156NCEN  Not Seasonally Adjusted                       NSA
# PPAAGA13073A156NCEN  Not Seasonally Adjusted                       NSA
# PPAAKY21147A156NCEN  Not Seasonally Adjusted                       NSA
# PPAACT09009A156NCEN  Not Seasonally Adjusted                       NSA
#
#                                  last_updated popularity  \
# series id
# PPAAUS00000A156NCEN 2023-12-14 12:51:03-06:00         50
# PPAACA06037A156NCEN 2023-12-14 12:46:12-06:00         12
# PPAACA06000A156NCEN 2023-12-14 12:51:04-06:00         11
# PPAAPA42000A156NCEN 2023-12-14 12:51:17-06:00          7
# PPAAIN18000A156NCEN 2023-12-14 12:51:04-06:00          7
# ...                                       ...        ...
# PPAAWI55000A156NCEN 2023-12-14 13:10:20-06:00          1
# PPAACA06093A156NCEN 2023-12-14 12:57:32-06:00          1
# PPAAGA13073A156NCEN 2023-12-14 12:57:26-06:00          1
# PPAAKY21147A156NCEN 2023-12-14 13:33:30-06:00          1
# PPAACT09009A156NCEN 2022-12-21 09:44:21-06:00          1
#
#                                                                  notes
# series id
# PPAAUS00000A156NCEN  The U.S. Census Bureau provides annual estimat...
# PPAACA06037A156NCEN  The U.S. Census Bureau provides annual estimat...
# PPAACA06000A156NCEN  The U.S. Census Bureau provides annual estimat...
# PPAAPA42000A156NCEN  The U.S. Census Bureau provides annual estimat...
# PPAAIN18000A156NCEN  The U.S. Census Bureau provides annual estimat...
# ...                                                                ...
# PPAAWI55000A156NCEN  The U.S. Census Bureau provides annual estimat...
# PPAACA06093A156NCEN  The U.S. Census Bureau provides annual estimat...
# PPAAGA13073A156NCEN  The U.S. Census Bureau provides annual estimat...
# PPAAKY21147A156NCEN  The U.S. Census Bureau provides annual estimat...
# PPAACT09009A156NCEN  The U.S. Census Bureau provides annual estimat...
#
# [567 rows x 15 columns]

# %%
# Percent of People of All Ages in Poverty
