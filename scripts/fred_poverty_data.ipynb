# %%
import os
from dotenv import load_dotenv
import requests
import pandas as pd
import matplotlib as plt
import json
from fredapi import Fred

# %%
load_dotenv()
fred_api_key = os.getenv("FRED_API_KEY")
fred = Fred(api_key=fred_api_key)

# %%
# Percent of People of All Ages in Poverty
df_pov = fred.search('Percent of People of All Ages in Poverty')
# df_inc = df_inc.query('units == "Percent"')

df_pov = df_pov.loc[df_pov['title'].str.contains('Percent of People of All Ages in Poverty')]

# %%
df_pov.shape
# Out:
# (575, 15)

# %%
df_pov
# Out:
#                                               id realtime_start realtime_end  \
# series id
# PPAAUS00000A156NCEN          PPAAUS00000A156NCEN     2024-02-14   2024-02-14
# PPAACA06000A156NCEN          PPAACA06000A156NCEN     2024-02-14   2024-02-14
# PPAANC37000A156NCEN          PPAANC37000A156NCEN     2024-02-14   2024-02-14
# PPAAPA42000A156NCEN          PPAAPA42000A156NCEN     2024-02-14   2024-02-14
# PPAAGA13015A156NCEN          PPAAGA13015A156NCEN     2024-02-14   2024-02-14
# ...                                          ...            ...          ...
# PPCILBAANC37103A156NCEN  PPCILBAANC37103A156NCEN     2024-02-14   2024-02-14
# PPCILBAAMT30051A156NCEN  PPCILBAAMT30051A156NCEN     2024-02-14   2024-02-14
# PPCILBAATX48013A156NCEN  PPCILBAATX48013A156NCEN     2024-02-14   2024-02-14
# PPCILBAAMS28133A156NCEN  PPCILBAAMS28133A156NCEN     2024-02-14   2024-02-14
# PPCILBAANC37175A156NCEN  PPCILBAANC37175A156NCEN     2024-02-14   2024-02-14
#
# ...

# %%
# Percent of People of All Ages in Poverty
