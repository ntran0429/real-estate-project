# %%
import os
from dotenv import load_dotenv
import requests
import pandas as pd
import matplotlib as plt
import json
from fredapi import Fred

# %%
load_dotenv()
fred_api_key = os.getenv("FRED_API_KEY")
fred = Fred(api_key=fred_api_key)

# %%
# Real per capita Personal Income by State
# Real per capita personal income is the real personal income divided by midyear population.
df_inc = fred.search('Real Per Capita Personal Income')
# df_inc = df_inc.query('units == "Dollars"')
# filter for only Real per capita Personal Income in title
df_inc = df_inc.loc[df_inc['title'].str.contains('Real Per Capita Personal Income')]

# %%
df_inc['seasonal_adjustment'].value_counts()
# Out:
# seasonal_adjustment
# Not Seasonally Adjusted            537
# Seasonally Adjusted Annual Rate      7
# Name: count, dtype: int64

# %%
df_inc['units'].value_counts()
# Out:
# units
# Chained 2017 Dollars    540
# Chained 2012 Dollars      2
# Chained 2017 Dollar       1
# Chained 2009 Dollars      1
# Name: count, dtype: int64

# %%
df_inc.shape
# Out:
# (544, 15)

# %%
df_inc
# Out:
#                     id realtime_start realtime_end  \
# series id
# RPIPCUS        RPIPCUS     2024-01-26   2024-01-26
# CARPIPC        CARPIPC     2024-01-26   2024-01-26
# RPIPC19820  RPIPC19820     2024-01-26   2024-01-26
# NYRPIPC        NYRPIPC     2024-01-26   2024-01-26
# RPIPC12060  RPIPC12060     2024-01-26   2024-01-26
# ...                ...            ...          ...
# NCNMPRPIPC  NCNMPRPIPC     2024-01-26   2024-01-26
# RPIPC35840  RPIPC35840     2024-01-26   2024-01-26
# RPIPC22220  RPIPC22220     2024-01-26   2024-01-26
# DCNMPRPIPC  DCNMPRPIPC     2024-01-26   2024-01-26
# RPIPC34820  RPIPC34820     2024-01-26   2024-01-26
#
#                                                         title  \
# series id
# RPIPCUS     Real Per Capita Personal Income for United States
# CARPIPC        Real Per Capita Personal Income for California
# RPIPC19820  Real Per Capita Personal Income for Detroit-Wa...
# NYRPIPC          Real Per Capita Personal Income for New York
# RPIPC12060  Real Per Capita Personal Income for Atlanta-Sa...
# ...                                                       ...
# NCNMPRPIPC  Real Per Capita Personal Income: Nonmetropolit...
# RPIPC35840  Real Per Capita Personal Income for North Port...
# RPIPC22220  Real Per Capita Personal Income for Fayettevil...
# DCNMPRPIPC  Real Per Capita Personal Income: Nonmetropolit...
# RPIPC34820  Real Per Capita Personal Income for Myrtle Bea...
#
#            observation_start observation_end frequency frequency_short  \
# series id
# RPIPCUS           2008-01-01      2022-01-01    Annual               A
# CARPIPC           2008-01-01      2022-01-01    Annual               A
# RPIPC19820        2008-01-01      2022-01-01    Annual               A
# NYRPIPC           2008-01-01      2022-01-01    Annual               A
# RPIPC12060        2008-01-01      2022-01-01    Annual               A
# ...                      ...             ...       ...             ...
# NCNMPRPIPC        2008-01-01      2022-01-01    Annual               A
# RPIPC35840        2008-01-01      2022-01-01    Annual               A
# RPIPC22220        2008-01-01      2022-01-01    Annual               A
# DCNMPRPIPC        2008-01-01      2022-01-01    Annual               A
# RPIPC34820        2008-01-01      2022-01-01    Annual               A
#
#                            units  units_short      seasonal_adjustment  \
# series id
# RPIPCUS     Chained 2017 Dollars  Chn. 2017 $  Not Seasonally Adjusted
# CARPIPC     Chained 2017 Dollars  Chn. 2017 $  Not Seasonally Adjusted
# RPIPC19820  Chained 2017 Dollars  Chn. 2017 $  Not Seasonally Adjusted
# NYRPIPC     Chained 2017 Dollars  Chn. 2017 $  Not Seasonally Adjusted
# RPIPC12060  Chained 2017 Dollars  Chn. 2017 $  Not Seasonally Adjusted
# ...                          ...          ...                      ...
# NCNMPRPIPC  Chained 2017 Dollars  Chn. 2017 $  Not Seasonally Adjusted
# RPIPC35840  Chained 2017 Dollars  Chn. 2017 $  Not Seasonally Adjusted
# RPIPC22220  Chained 2017 Dollars  Chn. 2017 $  Not Seasonally Adjusted
# DCNMPRPIPC  Chained 2017 Dollars  Chn. 2017 $  Not Seasonally Adjusted
# RPIPC34820  Chained 2017 Dollars  Chn. 2017 $  Not Seasonally Adjusted
#
#            seasonal_adjustment_short               last_updated popularity  \
# series id
# RPIPCUS                          NSA  2023-12-14 11:56:02-06:00         40
# CARPIPC                          NSA  2023-12-14 11:56:03-06:00         10
# RPIPC19820                       NSA  2023-12-14 11:58:32-06:00          7
# NYRPIPC                          NSA  2023-12-14 11:56:37-06:00          5
# RPIPC12060                       NSA  2023-12-14 11:58:36-06:00          4
# ...                              ...                        ...        ...
# NCNMPRPIPC                       NSA  2023-12-14 12:00:33-06:00          0
# RPIPC35840                       NSA  2023-12-14 12:00:00-06:00          0
# RPIPC22220                       NSA  2023-12-14 11:59:38-06:00          0
# DCNMPRPIPC                       NSA  2023-12-14 12:00:16-06:00          0
# RPIPC34820                       NSA  2023-12-14 12:00:00-06:00          0
#
#                                                         notes
# series id
# RPIPCUS     Real per capita personal income is the real pe...
# CARPIPC     Real per capita personal income is the real pe...
# RPIPC19820  Real per capita personal income is the real pe...
# NYRPIPC     Real per capita personal income is the real pe...
# RPIPC12060  Real per capita personal income is the real pe...
# ...                                                       ...
# NCNMPRPIPC  Real per capita personal income is the real pe...
# RPIPC35840  Real per capita personal income is the real pe...
# RPIPC22220  Real per capita personal income is the real pe...
# DCNMPRPIPC  Real per capita personal income is the real pe...
# RPIPC34820  Real per capita personal income is the real pe...
#
# [544 rows x 15 columns]

# %%
df_inc[df_inc['id'] == 'TXRPIPC']
# Out:
#                 id realtime_start realtime_end  \
# series id
# TXRPIPC    TXRPIPC     2024-01-26   2024-01-26
#
#                                                title observation_start  \
# series id
# TXRPIPC    Real Per Capita Personal Income for Texas        2008-01-01
#
#           observation_end frequency frequency_short                 units  \
# series id
# TXRPIPC        2022-01-01    Annual               A  Chained 2017 Dollars
#
#            units_short      seasonal_adjustment seasonal_adjustment_short  \
# series id
# TXRPIPC    Chn. 2017 $  Not Seasonally Adjusted                       NSA
#
#                         last_updated popularity  \
# series id
# TXRPIPC    2023-12-14 11:56:45-06:00          4
#
#                                                        notes
# series id
# TXRPIPC    Real per capita personal income is the real pe...

# %%
# drop rows in 'id' column that do not end with RPI
inc_result = df_inc[df_inc['id'].str.endswith('RPIPC')]

# %%
inc_result.id.unique()
# Out:
# array(['CARPIPC', 'NYRPIPC', 'TXRPIPC', 'WARPIPC', 'MARPIPC', 'CORPIPC',
#        'FLRPIPC', 'MNRPIPC', 'DCRPIPC', 'WIRPIPC', 'MIRPIPC', 'KYMPRPIPC',
#        'HINMPRPIPC', 'NMMPRPIPC', 'NDMPRPIPC', 'SDMPRPIPC', 'SCMPRPIPC',
#        'NHNMPRPIPC', 'ALRPIPC', 'RIRPIPC', 'CTRPIPC', 'NJRPIPC',
#        'VARPIPC', 'SCRPIPC', 'GARPIPC', 'WVRPIPC', 'AZRPIPC', 'TNRPIPC',
#        'PARPIPC', 'MIMPRPIPC', 'NCRPIPC', 'MERPIPC', 'UTRPIPC',
#        'IDNMPRPIPC', 'MDRPIPC', 'ILRPIPC', 'HIRPIPC', 'WYRPIPC',
#        'MNNMPRPIPC', 'NENMPRPIPC', 'ARRPIPC', 'OHRPIPC', 'SDRPIPC',
#        'NMRPIPC', 'MSRPIPC', 'IDRPIPC', 'GAMPRPIPC', 'LARPIPC', 'AKRPIPC',
#        'AZMPRPIPC', 'OKRPIPC', 'VTNMPRPIPC', 'NDRPIPC', 'KYRPIPC',
#        'ORRPIPC', 'NHRPIPC', 'ORMPRPIPC', 'MTRPIPC', 'KSRPIPC', 'VTRPIPC',
#        'INRPIPC', 'NVRPIPC', 'MORPIPC', 'IARPIPC', 'DERPIPC', 'NERPIPC',
#        'CTNMPRPIPC', 'GANMPRPIPC', 'AZNMPRPIPC', 'OKMPRPIPC',
#        'NMNMPRPIPC', 'WIMPRPIPC', 'MTMPRPIPC', 'MTNMPRPIPC', 'TXMPRPIPC',
#        'WINMPRPIPC', 'PAMPRPIPC', 'NYMPRPIPC', 'MINMPRPIPC', 'DENMPRPIPC',
#        'ILNMPRPIPC', 'CANMPRPIPC', 'ARMPRPIPC', 'TNNMPRPIPC',
#        'MDNMPRPIPC', 'NCMPRPIPC', 'IANMPRPIPC', 'MANMPRPIPC',
#        'OKNMPRPIPC', 'DCMPRPIPC', 'NVMPRPIPC', 'OHMPRPIPC', 'IDMPRPIPC',
#        'COMPRPIPC', 'CONMPRPIPC', 'NYNMPRPIPC', 'VANMPRPIPC',
#        'SCNMPRPIPC', 'UTMPRPIPC', 'AKMPRPIPC', 'KSMPRPIPC', 'ALMPRPIPC',
#        'DEMPRPIPC', 'KSNMPRPIPC', 'NVNMPRPIPC', 'FLNMPRPIPC',
#        'WYNMPRPIPC', 'CTMPRPIPC', 'KYNMPRPIPC', 'NJNMPRPIPC', 'INMPRPIPC',
#        'INNMPRPIPC', 'MDMPRPIPC', 'MSMPRPIPC', 'IAMPRPIPC', 'MEMPRPIPC',
#        'HIMPRPIPC', 'FLMPRPIPC', 'OHNMPRPIPC', 'UTNMPRPIPC', 'VTMPRPIPC',
#        'WYMPRPIPC', 'ILMPRPIPC', 'MENMPRPIPC', 'MOMPRPIPC', 'NEMPRPIPC',
#        'TXNMPRPIPC', 'VAMPRPIPC', 'AKNMPRPIPC', 'LAMPRPIPC', 'MNMPRPIPC',
#        'ORNMPRPIPC', 'TNMPRPIPC', 'ALNMPRPIPC', 'CAMPRPIPC', 'NJMPRPIPC',
#        'WAMPRPIPC', 'ARNMPRPIPC', 'MONMPRPIPC', 'LANMPRPIPC', 'RIMPRPIPC',
#        'MAMPRPIPC', 'NHMPRPIPC', 'WANMPRPIPC', 'WVMPRPIPC', 'MSNMPRPIPC',
#        'NDNMPRPIPC', 'PANMPRPIPC', 'RINMPRPIPC', 'SDNMPRPIPC',
#        'WVNMPRPIPC', 'NCNMPRPIPC', 'DCNMPRPIPC'], dtype=object)

# %%
# filter for rows with ids whose length is 7
inc_result = inc_result[inc_result['id'].str.len() == 7]

# %%
inc_result.shape
# Out:
# (51, 15)

# %%
inc_result.id.unique()
# missing PR data
# Out:
# array(['CARPIPC', 'NYRPIPC', 'TXRPIPC', 'WARPIPC', 'MARPIPC', 'CORPIPC',
#        'FLRPIPC', 'MNRPIPC', 'DCRPIPC', 'WIRPIPC', 'MIRPIPC', 'ALRPIPC',
#        'RIRPIPC', 'CTRPIPC', 'NJRPIPC', 'VARPIPC', 'SCRPIPC', 'GARPIPC',
#        'WVRPIPC', 'AZRPIPC', 'TNRPIPC', 'PARPIPC', 'NCRPIPC', 'MERPIPC',
#        'UTRPIPC', 'MDRPIPC', 'ILRPIPC', 'HIRPIPC', 'WYRPIPC', 'ARRPIPC',
#        'OHRPIPC', 'SDRPIPC', 'NMRPIPC', 'MSRPIPC', 'IDRPIPC', 'LARPIPC',
#        'AKRPIPC', 'OKRPIPC', 'NDRPIPC', 'KYRPIPC', 'ORRPIPC', 'NHRPIPC',
#        'MTRPIPC', 'KSRPIPC', 'VTRPIPC', 'INRPIPC', 'NVRPIPC', 'MORPIPC',
#        'IARPIPC', 'DERPIPC', 'NERPIPC'], dtype=object)

# %%
all_result =[]

for id in inc_result.index:
    result = fred.get_series(id)
    result = result.to_frame(name = id)
    all_result.append(result)

# %%
all_result[1]
# Out:
#             NYRPIPC
# 2008-01-01  48246.0
# 2009-01-01  47526.0
# 2010-01-01  48800.0
# 2011-01-01  49369.0
# 2012-01-01  50801.0
# 2013-01-01  50345.0
# 2014-01-01  51565.0
# 2015-01-01  53135.0
# 2016-01-01  54059.0
# 2017-01-01  56703.0
# 2018-01-01  57543.0
# 2019-01-01  58669.0
# 2020-01-01  60801.0
# 2021-01-01  63666.0
# 2022-01-01  60472.0

# %%
inc_state = pd.concat(all_result, axis=1)

# %%
inc_state.tail()
# Out:
#             CARPIPC  NYRPIPC  TXRPIPC  WARPIPC  MARPIPC  CORPIPC  FLRPIPC  \
# 2018-01-01  53481.0  57543.0  51578.0  54841.0  63345.0  56587.0  49932.0
# 2019-01-01  55915.0  58669.0  52351.0  56828.0  65445.0  57850.0  52072.0
# 2020-01-01  60011.0  60801.0  53456.0  60169.0  68032.0  59863.0  53888.0
# 2021-01-01  63271.0  63666.0  56565.0  62680.0  71971.0  64282.0  57193.0
# 2022-01-01  59103.0  60472.0  55382.0  59175.0  66701.0  63875.0  54746.0
#
#             MNRPIPC  DCRPIPC  WIRPIPC  ...  NHRPIPC  MTRPIPC  KSRPIPC  \
# 2018-01-01  55425.0  72433.0  52805.0  ...  57229.0  50187.0  53374.0
# 2019-01-01  56672.0  74097.0  53670.0  ...  59512.0  50986.0  54358.0
# 2020-01-01  59982.0  77515.0  57334.0  ...  61785.0  55822.0  57114.0
# 2021-01-01  62468.0  80287.0  59557.0  ...  64766.0  58704.0  58997.0
# 2022-01-01  60785.0  73383.0  57465.0  ...  59247.0  58297.0  57958.0
#
#             VTRPIPC  INRPIPC  NVRPIPC  MORPIPC  IARPIPC  DERPIPC  NERPIPC
# 2018-01-01  50638.0  49297.0  50302.0  49937.0  52149.0  52109.0  54975.0
# 2019-01-01  52739.0  50349.0  50824.0  50619.0  52319.0  52615.0  55874.0
# 2020-01-01  54402.0  54014.0  53887.0  54141.0  55518.0  55233.0  58531.0
# 2021-01-01  57077.0  56596.0  58810.0  56045.0  59451.0  55553.0  62680.0
# 2022-01-01  53806.0  54811.0  55582.0  54753.0  58769.0  55709.0  61750.0
#
# [5 rows x 51 columns]

# %%
# create a mapping dict to change column names using list comprehension
id_to_state = df_inc['title'].str.replace('Real Per Capita Personal Income for ','').to_dict()

# %%
inc_state.columns
# Out:
# Index(['CARPIPC', 'NYRPIPC', 'TXRPIPC', 'WARPIPC', 'MARPIPC', 'CORPIPC',
#        'FLRPIPC', 'MNRPIPC', 'DCRPIPC', 'WIRPIPC', 'MIRPIPC', 'ALRPIPC',
#        'RIRPIPC', 'CTRPIPC', 'NJRPIPC', 'VARPIPC', 'SCRPIPC', 'GARPIPC',
#        'WVRPIPC', 'AZRPIPC', 'TNRPIPC', 'PARPIPC', 'NCRPIPC', 'MERPIPC',
#        'UTRPIPC', 'MDRPIPC', 'ILRPIPC', 'HIRPIPC', 'WYRPIPC', 'ARRPIPC',
#        'OHRPIPC', 'SDRPIPC', 'NMRPIPC', 'MSRPIPC', 'IDRPIPC', 'LARPIPC',
#        'AKRPIPC', 'OKRPIPC', 'NDRPIPC', 'KYRPIPC', 'ORRPIPC', 'NHRPIPC',
#        'MTRPIPC', 'KSRPIPC', 'VTRPIPC', 'INRPIPC', 'NVRPIPC', 'MORPIPC',
#        'IARPIPC', 'DERPIPC', 'NERPIPC'],
#       dtype='object')

# %%
# change column names using list comprehension
inc_state.columns = [id_to_state[d] for d in inc_state.columns]

# %%
inc_state.columns
# Out:
# Index(['California', 'New York', 'Texas', 'Washington', 'Massachusetts',
#        'Colorado', 'Florida', 'Minnesota', 'District of Columbia', 'Wisconsin',
#        'Michigan', 'Alabama', 'Rhode Island', 'Connecticut', 'New Jersey',
#        'Virginia', 'South Carolina', 'Georgia', 'West Virginia', 'Arizona',
#        'Tennessee', 'Pennsylvania', 'North Carolina', 'Maine', 'Utah',
#        'Maryland', 'Illinois', 'Hawaii', 'Wyoming', 'Arkansas', 'Ohio',
#        'South Dakota', 'New Mexico', 'Mississippi', 'Idaho', 'Louisiana',
#        'Alaska', 'Oklahoma', 'North Dakota', 'Kentucky', 'Oregon',
#        'New Hampshire', 'Montana', 'Kansas', 'Vermont', 'Indiana', 'Nevada',
#        'Missouri', 'Iowa', 'Delaware', 'Nebraska'],
#       dtype='object')

# %%
# export inc_state to csv
inc_state.to_csv('../cleansed data/RPIPC_income_state.csv')
